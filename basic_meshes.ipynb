# %% [markdown]
# <a href="https://colab.research.google.com/github/van-dang/FEniCS-Colab/blob/master/basic_meshes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf *
# Copy file from the internet.
# !wget https://raw.githubusercontent.com/toastpp/toastpp/master/examples/matlab/gmsh/sphere.geo

# # # # # # # # # # Run with Gmsh # # # # # # # # # # # #
# !apt-get install gmsh
# !gmsh --version
# !gmsh -3 sphere.geo -o sphere.msh

# # # # # # # # # # Convert mesh by meshio # # # # # # # # 
# !pip install -U meshio
# !apt-get install python-lxml
# !meshio-convert sphere.msh sphere.vtk # Output for Paraview

# Save to your local computer
# from google.colab import files
# files.download('sphere.msh')

# print("Complete! A mesh file 'sphere.msh' is downloaded to your computer!")
# print("Install GMSH (http://gmsh.info/) on your computer to see the mesh.")
# Out:
# Redirecting output to ‘wget-log’.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gmsh is already the newest version (2.15.0+dfsg1-3).
# The following packages were automatically installed and are no longer required:
#   adwaita-icon-theme at-spi2-core dconf-gsettings-backend dconf-service
#   fontconfig gdal-data glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gstreamer1.0-plugins-base
#   gtk-update-icon-cache hicolor-icon-theme humanity-icon-theme i965-va-driver
#   iso-codes javascript-common libaacs0 libarmadillo7 libarpack2
#   libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data libatspi2.0-0 libaudio2
#   libavahi-client3 libavahi-common-data libavahi-common3 libavcodec57
#   libavformat57 libavutil55 libbdplus0 libbluray2 libboost-filesystem1.62.0
#   libboost-system1.62.0 libcairo-gobject2 libcairo2 libcap2-bin libcapnp-0.5.3
#   libcdparanoia0 libchromaprint1 libcolord2 libcroco3 libcrystalhd3 libcups2
#   libdap25 libdapclient6v5 libdatrie1 libdconf1 libdouble-conversion1
#   libegl1-mesa libepoxy0 libepsilon1 libevdev2 libfreexl1 libfyba0
#   libgail-common libgail18 libgbm1 libgdal20 libgdk-pixbuf2.0-0
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgeos-3.5.1 libgeos-c1v5
#   libgeotiff2 libgif7 libgme0 libgraphite2-3 libgsm1
#   libgstreamer-plugins-base1.0-0 libgstreamer1.0-0 libgtk-3-0 libgtk-3-bin
#   libgtk-3-common libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libgudev-1.0-0
#   libharfbuzz0b libhdf4-0-alt libinput-bin libinput10 libjbig0 libjs-jquery
#   libjs-sphinxdoc libjs-underscore libjson-c3 libjson-glib-1.0-0
#   libjson-glib-1.0-common libjsoncpp1 libkmlbase1 libkmldom1 libkmlengine1
#   liblcms2-2 libminizip1 libmirclient9 libmircommon7 libmircore1
#   libmirprotobuf3 libmng2 libmp3lame0 libmpg123-0 libmtdev1 libmysqlclient20
#   libnetcdf-c++4 libnetcdf11 libnotify4 libodbc1 libogdi3.2 libogg0
#   libopenjp2-7 libopenmpt0 libopus0 liborc-0.4-0 libpam-cap libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpixman-1-0 libpoppler68 libpq5
#   libproj12 libprotobuf-lite10 libproxy1v5 libqhull7 libqt4-dbus
#   libqt4-declarative libqt4-designer libqt4-help libqt4-network libqt4-script
#   libqt4-scripttools libqt4-sql libqt4-sql-mysql libqt4-svg libqt4-test
#   libqt4-xml libqt4-xmlpatterns libqt5core5a libqt5dbus5 libqt5gui5
#   libqt5network5 libqt5opengl5 libqt5printsupport5 libqt5qml5 libqt5quick5
#   libqt5sql5 libqt5sql5-sqlite libqt5svg5 libqt5webkit5 libqt5widgets5
#   libqtassistantclient4 libqtcore4 libqtdbus4 libqtgui4 librest-0.7-0
#   librsvg2-2 librsvg2-common libshine3 libsnappy1v5 libsoup-gnome2.4-1
#   libsoup2.4-1 libsoxr0 libspatialite7 libspeex1 libssh-gcrypt-4 libsuperlu5
#   libswresample2 libswscale4 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 liburiparser1 libva-drm1 libva-x11-1 libva1 libvdpau1
#   libvisual-0.4-0 libvorbis0a libvorbisenc2 libvorbisfile3 libvpx4 libvtk6.3
#   libvtk6.3-qt libwacom-bin libwacom-common libwacom2 libwavpack1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1-mesa
#   libwayland-server0 libwebp6 libwebpmux3 libwxbase3.0-0v5 libwxgtk3.0-0v5
#   libx264-148 libx265-130 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-randr0 libxcb-render-util0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-util1 libxcb-xfixes0 libxcb-xinerama0 libxcb-xkb1 libxcomposite1
#   libxerces-c3.1 libxi6 libxkbcommon-x11-0 libxkbcommon0 libxrandr2 libxt6
#   libxtst6 libxvidcore4 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mysql-common notification-daemon odbcinst
#   odbcinst1debian2 poppler-data proj-bin proj-data python-apptools
#   python-asn1crypto python-attr python-autobahn python-cbor
#   python-cffi-backend python-click python-colorama python-concurrent.futures
#   python-configobj python-constantly python-cryptography python-enum34
#   python-envisage python-idna python-incremental python-ipaddress python-lz4
#   python-mpi4py python-msgpack python-nacl python-numpy python-olefile
#   python-openssl python-pam python-pil python-pyasn1 python-pyasn1-modules
#   python-pyface python-pygments python-qrcode python-qt4 python-serial
#   python-service-identity python-sip python-snappy python-traits
#   python-traitsui python-trollius python-twisted python-twisted-bin
#   python-twisted-core python-txaio python-vtk6 python-wxgtk3.0
#   python-wxversion python-zope.interface qdbus qt-at-spi qt5-gtk-platformtheme
#   qtchooser qtcore4-l10n qttranslations5-l10n ubuntu-mono va-driver-all
#   vdpau-driver-all xkb-data
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# 2.15.0
# [c425ec6200e1:06540] *** Process received signal ***
# [c425ec6200e1:06540] Signal: Segmentation fault (11)
# [c425ec6200e1:06540] Signal code: Address not mapped (1)
# [c425ec6200e1:06540] Failing at address: 0x7f68c64fb29e
# [c425ec6200e1:06540] [ 0] /lib/x86_64-linux-gnu/libpthread.so.0(+0x13150)[0x7f68c934c150]
# [c425ec6200e1:06540] [ 1] /lib/x86_64-linux-gnu/libc.so.6(getenv+0xad)[0x7f68c8f946bd]
# [c425ec6200e1:06540] [ 2] /usr/lib/x86_64-linux-gnu/libtcmalloc.so.4(_ZN13TCMallocGuardD1Ev+0x34)[0x7f68c97f7d64]
# [c425ec6200e1:06540] [ 3] /lib/x86_64-linux-gnu/libc.so.6(__cxa_finalize+0x9a)[0x7f68c8f9523a]
# [c425ec6200e1:06540] [ 4] /usr/lib/x86_64-linux-gnu/libtcmalloc.so.4(+0x13bd3)[0x7f68c97f5bd3]
# [c425ec6200e1:06540] *** End of error message ***
# Info    : Running 'gmsh -3 sphere.geo -o sphere.msh' [Gmsh 2.15.0, 1 node, max. 1 thread]
# Info    : Started on Sat Sep  8 21:04:47 2018
# Info    : Reading 'sphere.geo'...
# Info    : Done reading 'sphere.geo'
# Info    : Finalized high order topology of periodic connections
# Info    : Meshing 1D...
# Info    : Meshing curve 1 (Circle)
# Info    : Meshing curve 2 (Circle)
# Info    : Meshing curve 3 (Circle)
# Info    : Meshing curve 4 (Circle)
# Info    : Meshing curve 5 (Circle)
# Info    : Meshing curve 6 (Circle)
# Info    : Meshing curve 7 (Circle)
# Info    : Meshing curve 8 (Circle)
# Info    : Meshing curve 9 (Circle)
# Info    : Meshing curve 10 (Circle)
# Info    : Meshing curve 11 (Circle)
# Info    : Meshing curve 12 (Circle)
# Info    : Done meshing 1D (0.002045 s)
# Info    : Meshing 2D...
# Info    : Meshing surface 14 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 16 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 18 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 20 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 22 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 24 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 26 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 28 (Ruled surface, MeshAdapt)
# Info    : Done meshing 2D (0.706834 s)
# Info    : Meshing 3D...
# Info    : Delaunay Meshing 1 volumes with 1 connected components
# Info    : Meshing volume 30 (Delaunay)
# Delaunizing vertices...
# Delaunay seconds:  0.177642
# Creating surface mesh ...
# Surface mesh seconds:  0.004852
# Recovering boundaries...
# Boundary recovery seconds:  0.005144
# Removing exterior tetrahedra ...
# Exterior tets removal seconds:  0.000719
# Recovering Delaunayness...
# Delaunay recovery seconds:  0.048148
# Optimizing mesh...
# Optimization seconds:  0.002548
#
# Writing nodes.
# Writing elements.
# Writing faces.
# Writing edges.
#
# Output seconds:  0.003294
# Total running seconds:  0.24302
#
# Statistics:
#
#   Input points: 1505
#   Input facets: 3006
#   Input segments: 4509
#   Input holes: 0
#   Input regions: 0
#
#   Mesh points: 1505
#   Mesh tetrahedra: 4330
#   Mesh faces: 10163
#   Mesh edges: 7337
#   Mesh faces on facets: 3006
#   Mesh edges on segments: 4509
#
# Info    : 1505 points 7337 edges and 3006 faces in the initial mesh
# Info    : Found region 30
# Info    : 0 points created - Worst tet radius is 10.9708 (PTS removed 0 0)
# Info    : 3D point insertion terminated (3460 points created):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 points could not be inserted
# Info    :  - 16979 tetrahedra created in 0.19494 sec. (87098 tets/sec.)
# Info    : Done meshing 3D (0.484766 s)
# Info    : 3461 vertices 20184 elements
# Info    : Writing 'sphere.msh'...
# Info    : Done writing 'sphere.msh'
# Info    : Stopped on Sat Sep  8 21:04:48 2018
# [c425ec6200e1:06548] *** Process received signal ***
# [c425ec6200e1:06548] Signal: Segmentation fault (11)
# [c425ec6200e1:06548] Signal code: Address not mapped (1)
# [c425ec6200e1:06548] Failing at address: 0x7f3d996f929e
# [c425ec6200e1:06548] [ 0] /lib/x86_64-linux-gnu/libpthread.so.0(+0x13150)[0x7f3d9c54a150]
# [c425ec6200e1:06548] [ 1] /lib/x86_64-linux-gnu/libc.so.6(getenv+0xad)[0x7f3d9c1926bd]
# [c425ec6200e1:06548] [ 2] /usr/lib/x86_64-linux-gnu/libtcmalloc.so.4(_ZN13TCMallocGuardD1Ev+0x34)[0x7f3d9c9f5d64]
# [c425ec6200e1:06548] [ 3] /lib/x86_64-linux-gnu/libc.so.6(__cxa_finalize+0x9a)[0x7f3d9c19323a]
# [c425ec6200e1:06548] [ 4] /usr/lib/x86_64-linux-gnu/libtcmalloc.so.4(+0x13bd3)[0x7f3d9c9f3bd3]
# [c425ec6200e1:06548] *** End of error message ***
# Requirement already up-to-date: meshio in /usr/local/lib/python2.7/dist-packages (2.2.5)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python2.7/dist-packages (from meshio) (1.14.5)
# Requirement already satisfied, skipping upgrade: pipdate<0.4.0,>=0.3.0 in /usr/local/lib/python2.7/dist-packages (from meshio) (0.3.2)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python2.7/dist-packages (from pipdate<0.4.0,>=0.3.0->meshio) (2.18.4)
# Requirement already satisfied, skipping upgrade: appdirs in /usr/local/lib/python2.7/dist-packages (from pipdate<0.4.0,>=0.3.0->meshio) (1.4.3)
# Requirement already satisfied, skipping upgrade: idna<2.7,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests->pipdate<0.4.0,>=0.3.0->meshio) (2.6)
# Requirement already satisfied, skipping upgrade: urllib3<1.23,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests->pipdate<0.4.0,>=0.3.0->meshio) (1.22)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests->pipdate<0.4.0,>=0.3.0->meshio) (2018.8.24)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests->pipdate<0.4.0,>=0.3.0->meshio) (3.0.4)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-lxml is already the newest version (4.0.0-1).
# The following packages were automatically installed and are no longer required:
#   adwaita-icon-theme at-spi2-core dconf-gsettings-backend dconf-service
#   fontconfig gdal-data glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gstreamer1.0-plugins-base
#   gtk-update-icon-cache hicolor-icon-theme humanity-icon-theme i965-va-driver
#   iso-codes javascript-common libaacs0 libarmadillo7 libarpack2
#   libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data libatspi2.0-0 libaudio2
#   libavahi-client3 libavahi-common-data libavahi-common3 libavcodec57
#   libavformat57 libavutil55 libbdplus0 libbluray2 libboost-filesystem1.62.0
#   libboost-system1.62.0 libcairo-gobject2 libcairo2 libcap2-bin libcapnp-0.5.3
#   libcdparanoia0 libchromaprint1 libcolord2 libcroco3 libcrystalhd3 libcups2
#   libdap25 libdapclient6v5 libdatrie1 libdconf1 libdouble-conversion1
#   libegl1-mesa libepoxy0 libepsilon1 libevdev2 libfreexl1 libfyba0
#   libgail-common libgail18 libgbm1 libgdal20 libgdk-pixbuf2.0-0
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgeos-3.5.1 libgeos-c1v5
#   libgeotiff2 libgif7 libgme0 libgraphite2-3 libgsm1
#   libgstreamer-plugins-base1.0-0 libgstreamer1.0-0 libgtk-3-0 libgtk-3-bin
#   libgtk-3-common libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libgudev-1.0-0
#   libharfbuzz0b libhdf4-0-alt libinput-bin libinput10 libjbig0 libjs-jquery
#   libjs-sphinxdoc libjs-underscore libjson-c3 libjson-glib-1.0-0
#   libjson-glib-1.0-common libjsoncpp1 libkmlbase1 libkmldom1 libkmlengine1
#   liblcms2-2 libminizip1 libmirclient9 libmircommon7 libmircore1
#   libmirprotobuf3 libmng2 libmp3lame0 libmpg123-0 libmtdev1 libmysqlclient20
#   libnetcdf-c++4 libnetcdf11 libnotify4 libodbc1 libogdi3.2 libogg0
#   libopenjp2-7 libopenmpt0 libopus0 liborc-0.4-0 libpam-cap libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpixman-1-0 libpoppler68 libpq5
#   libproj12 libprotobuf-lite10 libproxy1v5 libqhull7 libqt4-dbus
#   libqt4-declarative libqt4-designer libqt4-help libqt4-network libqt4-script
#   libqt4-scripttools libqt4-sql libqt4-sql-mysql libqt4-svg libqt4-test
#   libqt4-xml libqt4-xmlpatterns libqt5core5a libqt5dbus5 libqt5gui5
#   libqt5network5 libqt5opengl5 libqt5printsupport5 libqt5qml5 libqt5quick5
#   libqt5sql5 libqt5sql5-sqlite libqt5svg5 libqt5webkit5 libqt5widgets5
#   libqtassistantclient4 libqtcore4 libqtdbus4 libqtgui4 librest-0.7-0
#   librsvg2-2 librsvg2-common libshine3 libsnappy1v5 libsoup-gnome2.4-1
#   libsoup2.4-1 libsoxr0 libspatialite7 libspeex1 libssh-gcrypt-4 libsuperlu5
#   libswresample2 libswscale4 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 liburiparser1 libva-drm1 libva-x11-1 libva1 libvdpau1
#   libvisual-0.4-0 libvorbis0a libvorbisenc2 libvorbisfile3 libvpx4 libvtk6.3
#   libvtk6.3-qt libwacom-bin libwacom-common libwacom2 libwavpack1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1-mesa
#   libwayland-server0 libwebp6 libwebpmux3 libwxbase3.0-0v5 libwxgtk3.0-0v5
#   libx264-148 libx265-130 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-randr0 libxcb-render-util0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-util1 libxcb-xfixes0 libxcb-xinerama0 libxcb-xkb1 libxcomposite1
#   libxerces-c3.1 libxi6 libxkbcommon-x11-0 libxkbcommon0 libxrandr2 libxt6
#   libxtst6 libxvidcore4 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mysql-common notification-daemon odbcinst
#   odbcinst1debian2 poppler-data proj-bin proj-data python-apptools
#   python-asn1crypto python-attr python-autobahn python-cbor
#   python-cffi-backend python-click python-colorama python-concurrent.futures
#   python-configobj python-constantly python-cryptography python-enum34
#   python-envisage python-idna python-incremental python-ipaddress python-lz4
#   python-mpi4py python-msgpack python-nacl python-numpy python-olefile
#   python-openssl python-pam python-pil python-pyasn1 python-pyasn1-modules
#   python-pyface python-pygments python-qrcode python-qt4 python-serial
#   python-service-identity python-sip python-snappy python-traits
#   python-traitsui python-trollius python-twisted python-twisted-bin
#   python-twisted-core python-txaio python-vtk6 python-wxgtk3.0
#   python-wxversion python-zope.interface qdbus qt-at-spi qt5-gtk-platformtheme
#   qtchooser qtcore4-l10n qttranslations5-l10n ubuntu-mono va-driver-all
#   vdpau-driver-all xkb-data
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Number of points: 3461
# Number of elements:
#   triangle: 3006
#   line: 192
#   vertex: 7
#   tetra: 16979
# Cell data: gmsh:physical, gmsh:geometrical
