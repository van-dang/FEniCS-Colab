# %% [markdown]
# <a href="https://colab.research.google.com/github/van-dang/FEniCS-Colab/blob/master/multilayer_sphere.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# clean files
# !rm multi_layer_sphere* wget*

# # # # # # # # Download .geo file for gmsh # # # # # # # #
# !wget http://www.csc.kth.se/~vdnguyen/codes/multi_layer_sphere.geo

# # # # # # # # # # Run with Gmsh # # # # # # # # # # # #
# !apt-get install gmsh
# !gmsh --version
# !gmsh -3 multi_layer_sphere.geo -o multi_layer_sphere.msh

# Save to your local computer
from google.colab import files
files.download('multi_layer_sphere.msh')

# # # # # # # # # # Convert mesh by meshio # # # # # # # # 
# !pip install -U meshio
# !apt-get install python-lxml
# !meshio-convert multi_layer_sphere.msh multi_layer_sphere.vtu
# Out:
# rm: cannot remove 'multi_layer_sphere*': No such file or directory
# rm: cannot remove 'wget*': No such file or directory
# --2018-12-01 17:22:31--  http://www.csc.kth.se/~vdnguyen/codes/multi_layer_sphere.geo
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.227.116
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.227.116|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1688 (1.6K) [text/plain]
# Saving to: ‘multi_layer_sphere.geo’
#
# multi_layer_sphere. 100%[===================>]   1.65K  --.-KB/s    in 0s
#
# 2018-12-01 17:22:31 (186 MB/s) - ‘multi_layer_sphere.geo’ saved [1688/1688]
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gmsh is already the newest version (3.0.6+dfsg1-1).
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# 3.0.6
# [f7680fdd2aa6:07825] *** Process received signal ***
# [f7680fdd2aa6:07825] Signal: Segmentation fault (11)
# [f7680fdd2aa6:07825] Signal code: Address not mapped (1)
# [f7680fdd2aa6:07825] Failing at address: 0x7f9c3c71b20d
# [f7680fdd2aa6:07825] [ 0] /lib/x86_64-linux-gnu/libpthread.so.0(+0x12890)[0x7f9c3f3c5890]
# [f7680fdd2aa6:07825] [ 1] /lib/x86_64-linux-gnu/libc.so.6(getenv+0xa5)[0x7f9c3f004785]
# [f7680fdd2aa6:07825] [ 2] /usr/lib/x86_64-linux-gnu/libtcmalloc.so.4(_ZN13TCMallocGuardD1Ev+0x34)[0x7f9c3f86fe44]
# [f7680fdd2aa6:07825] [ 3] /lib/x86_64-linux-gnu/libc.so.6(__cxa_finalize+0xf5)[0x7f9c3f005615]
# [f7680fdd2aa6:07825] [ 4] /usr/lib/x86_64-linux-gnu/libtcmalloc.so.4(+0x13cb3)[0x7f9c3f86dcb3]
# [f7680fdd2aa6:07825] *** End of error message ***
# Info    : Running 'gmsh -3 multi_layer_sphere.geo -o multi_layer_sphere.msh' [Gmsh 3.0.6, 1 node, max. 1 thread]
# Info    : Started on Sat Dec  1 17:22:39 2018
# Info    : Reading 'multi_layer_sphere.geo'...
# Number compartments: 3
# Working on compartment 0
# Info    : 'multi_layer_sphere.geo', line 30 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 32 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 34 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 36 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 38 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 40 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 42 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 44 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Working on compartment 1
# Info    : 'multi_layer_sphere.geo', line 30 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 32 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 34 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 36 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 38 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 40 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 42 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 44 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Working on compartment 2
# Info    : 'multi_layer_sphere.geo', line 30 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 32 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 34 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 36 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 38 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 40 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 42 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : 'multi_layer_sphere.geo', line 44 : 'Ruled Surface' command is deprecated: use 'Surface' instead
# Info    : Finalized high order topology of periodic connections
# Info    : Meshing 1D...
# Info    : Meshing curve 1 (Circle)
# Info    : Meshing curve 2 (Circle)
# Info    : Meshing curve 3 (Circle)
# Info    : Meshing curve 4 (Circle)
# Info    : Meshing curve 5 (Circle)
# Info    : Meshing curve 6 (Circle)
# Info    : Meshing curve 7 (Circle)
# Info    : Meshing curve 8 (Circle)
# Info    : Meshing curve 9 (Circle)
# Info    : Meshing curve 10 (Circle)
# Info    : Meshing curve 11 (Circle)
# Info    : Meshing curve 12 (Circle)
# Info    : Meshing curve 31 (Circle)
# Info    : Meshing curve 32 (Circle)
# Info    : Meshing curve 33 (Circle)
# Info    : Meshing curve 34 (Circle)
# Info    : Meshing curve 35 (Circle)
# Info    : Meshing curve 36 (Circle)
# Info    : Meshing curve 37 (Circle)
# Info    : Meshing curve 38 (Circle)
# Info    : Meshing curve 39 (Circle)
# Info    : Meshing curve 40 (Circle)
# Info    : Meshing curve 41 (Circle)
# Info    : Meshing curve 42 (Circle)
# Info    : Meshing curve 61 (Circle)
# Info    : Meshing curve 62 (Circle)
# Info    : Meshing curve 63 (Circle)
# Info    : Meshing curve 64 (Circle)
# Info    : Meshing curve 65 (Circle)
# Info    : Meshing curve 66 (Circle)
# Info    : Meshing curve 67 (Circle)
# Info    : Meshing curve 68 (Circle)
# Info    : Meshing curve 69 (Circle)
# Info    : Meshing curve 70 (Circle)
# Info    : Meshing curve 71 (Circle)
# Info    : Meshing curve 72 (Circle)
# Info    : Done meshing 1D (0.006465 s)
# Info    : Meshing 2D...
# Info    : Meshing surface 14 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 16 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 18 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 20 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 22 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 24 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 26 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 28 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 44 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 46 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 48 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 50 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 52 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 54 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 56 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 58 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 74 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 76 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 78 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 80 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 82 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 84 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 86 (Ruled surface, MeshAdapt)
# Info    : Meshing surface 88 (Ruled surface, MeshAdapt)
# Info    : Done meshing 2D (1.47424 s)
# Info    : Meshing 3D...
# Info    : Delaunay Meshing 3 volumes with 1 connected components
# Info    : Meshing volume 91 (Delaunay)
# Info    : Meshing volume 92 (Delaunay)
# Info    : Meshing volume 93 (Delaunay)
# Delaunizing vertices...
# Delaunay seconds:  0.06448
# Creating surface mesh ...
# Surface mesh seconds:  0.009439
# Recovering boundaries...
# Boundary recovery seconds:  0.014235
# Removing exterior tetrahedra ...
# Exterior tets removal seconds:  0.001246
# Recovering Delaunayness...
# Delaunay recovery seconds:  0.020428
# Optimizing mesh...
# Optimization seconds:  0.004711
#
# Writing nodes.
# Writing elements.
# Writing faces.
# Writing edges.
#
# Output seconds:  0.007706
# Total running seconds:  0.123064
#
# Statistics:
#
#   Input points: 3294
#   Input facets: 6576
#   Input segments: 9864
#   Input holes: 0
#   Input regions: 0
#
#   Mesh points: 3294
#   Mesh tetrahedra: 14526
#   Mesh faces: 30865
#   Mesh edges: 19632
#   Mesh faces on facets: 6576
#   Mesh edges on segments: 9864
#
# Info    : 3294 points 19632 edges and 6576 faces in the initial mesh
# Info    : Found region 92
# Info    : Found region 91
# Info    : Found region 93
# Info    : 0 points created - Worst tet radius is 5.65891 (PTS removed 0 0)
# Info    : 499 points created - Worst tet radius is 1.31582 (PTS removed 0 1)
# Info    : 999 points created - Worst tet radius is 1.07751 (PTS removed 0 1)
# Info    : 3D point insertion terminated (4521 points created):
# Info    :  - 1 Delaunay cavities modified for star shapeness
# Info    :  - 1 points could not be inserted
# Info    :  - 22117 tetrahedra created in 0.155228 sec. (142480 tets/sec.)
# Info    : Done meshing 3D (0.439546 s)
# Info    : Optimizing 3D mesh...
# Info    : Optimizing volume 91
# Info    : Opti : STARTS with  5.16628E+02 QBAD  4.65617E-02 QAVG  6.32360E-01
# Info    : Opti : 0.00 < QUAL < 0.10 :         5 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :        27 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :        46 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :        79 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :       184 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :       643 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :       812 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :       670 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :       189 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        24 elements
# Info    : Opti : (74,0,5) =  5.16628E+02 QBAD  1.60629E-01 QAVG  6.45303E-01 (   0.002 sec)
# Info    : Opti : (76,0,5) =  5.16628E+02 QBAD  2.73087E-01 QAVG  6.45457E-01 (   0.002 sec)
# Info    : Opti : no ill-shaped tets in the mesh ;-)
# Info    : Opti : 0.00 < QUAL < 0.10 :         0 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :         0 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :         1 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :        80 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :       177 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :       642 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :       838 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :       666 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :       191 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        23 elements
# Info    : Optimizing volume 92
# Info    : Opti : STARTS with  1.23986E+03 QBAD  3.36316E-03 QAVG  6.17229E-01
# Info    : Opti : 0.00 < QUAL < 0.10 :        32 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :        95 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :       134 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :       190 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :       492 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :      1837 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :      1961 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :      1296 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :       536 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        31 elements
# Info    : Opti : (254,0,13) =  1.23986E+03 QBAD  1.80541E-01 QAVG  6.36653E-01 (   0.006 sec)
# Info    : Opti : (259,0,15) =  1.23986E+03 QBAD  2.84579E-01 QAVG  6.36996E-01 (   0.007 sec)
# Info    : Opti : (260,0,15) =  1.23986E+03 QBAD  3.00156E-01 QAVG  6.36995E-01 (   0.008 sec)
# Info    : Opti : no ill-shaped tets in the mesh ;-)
# Info    : Opti : 0.00 < QUAL < 0.10 :         0 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :         0 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :         0 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :       167 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :       464 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :      1847 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :      2023 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :      1329 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :       517 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        32 elements
# Info    : Optimizing volume 93
# Info    : Opti : STARTS with  2.41817E+03 QBAD  1.58288E-02 QAVG  6.15483E-01
# Info    : Opti : 0.00 < QUAL < 0.10 :        52 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :       202 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :       271 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :       428 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :      1033 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :      3435 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :      3842 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :      2440 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :      1072 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        59 elements
# Info    : Opti : (511,0,32) =  2.41817E+03 QBAD  1.67373E-01 QAVG  6.34150E-01 (   0.013 sec)
# Info    : Opti : (531,0,37) =  2.41817E+03 QBAD  2.42453E-01 QAVG  6.34607E-01 (   0.017 sec)
# Info    : Opti : no ill-shaped tets in the mesh ;-)
# Info    : Opti : 0.00 < QUAL < 0.10 :         0 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :         0 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :         9 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :       374 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :      1008 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :      3474 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :      3954 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :      2470 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :      1053 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        60 elements
# Info    : Done optimizing 3D mesh (0.056958 s)
# Info    : 4524 vertices 28428 elements
# Info    : Removing duplicate mesh vertices...
# Info    : Found 3 duplicate vertices
# Info    : Removed 3 duplicate mesh vertices
# Info    : Done removing duplicate mesh vertices
# Info    : Done reading 'multi_layer_sphere.geo'
# Info    : Finalized high order topology of periodic connections
# Info    : Meshing 3D...
# Info    : Delaunay Meshing 3 volumes with 1 connected components
# Info    : Meshing volume 91 (Delaunay)
# Info    : Meshing volume 92 (Delaunay)
# Info    : Meshing volume 93 (Delaunay)
# Delaunizing vertices...
# Delaunay seconds:  0.065836
# Creating surface mesh ...
# Surface mesh seconds:  0.006198
# Recovering boundaries...
# Boundary recovery seconds:  0.011948
# Removing exterior tetrahedra ...
# Exterior tets removal seconds:  0.000898
# Recovering Delaunayness...
# Delaunay recovery seconds:  0.017499
# Optimizing mesh...
# Optimization seconds:  0.005118
#
# Writing nodes.
# Writing elements.
# Writing faces.
# Writing edges.
#
# Output seconds:  0.007109
# Total running seconds:  0.114882
#
# Statistics:
#
#   Input points: 3294
#   Input facets: 6576
#   Input segments: 9864
#   Input holes: 0
#   Input regions: 0
#
#   Mesh points: 3294
#   Mesh tetrahedra: 14528
#   Mesh faces: 30869
#   Mesh edges: 19634
#   Mesh faces on facets: 6576
#   Mesh edges on segments: 9864
#
# Info    : 3294 points 19634 edges and 6576 faces in the initial mesh
# Info    : Found region 92
# Info    : Found region 91
# Info    : Found region 93
# Info    : 0 points created - Worst tet radius is 5.65891 (PTS removed 0 0)
# Info    : 499 points created - Worst tet radius is 1.31638 (PTS removed 0 1)
# Info    : 999 points created - Worst tet radius is 1.07904 (PTS removed 0 1)
# Info    : 3D point insertion terminated (4522 points created):
# Info    :  - 1 Delaunay cavities modified for star shapeness
# Info    :  - 1 points could not be inserted
# Info    :  - 22105 tetrahedra created in 0.161713 sec. (136692 tets/sec.)
# Info    : Done meshing 3D (0.471431 s)
# Info    : Optimizing 3D mesh...
# Info    : Optimizing volume 91
# Info    : Opti : STARTS with  5.16628E+02 QBAD  4.65617E-02 QAVG  6.32360E-01
# Info    : Opti : 0.00 < QUAL < 0.10 :         5 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :        27 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :        46 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :        79 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :       184 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :       643 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :       812 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :       670 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :       189 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        24 elements
# Info    : Opti : (74,0,5) =  5.16628E+02 QBAD  1.60629E-01 QAVG  6.45303E-01 (   0.001 sec)
# Info    : Opti : (76,0,5) =  5.16628E+02 QBAD  2.73087E-01 QAVG  6.45457E-01 (   0.001 sec)
# Info    : Opti : no ill-shaped tets in the mesh ;-)
# Info    : Opti : 0.00 < QUAL < 0.10 :         0 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :         0 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :         1 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :        80 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :       177 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :       642 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :       838 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :       666 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :       191 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        23 elements
# Info    : Optimizing volume 92
# Info    : Opti : STARTS with  1.23986E+03 QBAD  3.36316E-03 QAVG  6.17229E-01
# Info    : Opti : 0.00 < QUAL < 0.10 :        32 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :        95 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :       134 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :       190 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :       492 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :      1837 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :      1961 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :      1296 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :       536 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        31 elements
# Info    : Opti : (254,0,13) =  1.23986E+03 QBAD  1.80541E-01 QAVG  6.36653E-01 (   0.005 sec)
# Info    : Opti : (259,0,15) =  1.23986E+03 QBAD  2.84579E-01 QAVG  6.36996E-01 (   0.006 sec)
# Info    : Opti : (260,0,15) =  1.23986E+03 QBAD  3.00156E-01 QAVG  6.36995E-01 (   0.007 sec)
# Info    : Opti : no ill-shaped tets in the mesh ;-)
# Info    : Opti : 0.00 < QUAL < 0.10 :         0 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :         0 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :         0 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :       167 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :       464 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :      1847 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :      2023 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :      1329 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :       517 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        32 elements
# Info    : Optimizing volume 93
# Info    : Opti : STARTS with  2.41817E+03 QBAD  1.58288E-02 QAVG  6.16333E-01
# Info    : Opti : 0.00 < QUAL < 0.10 :        49 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :       198 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :       257 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :       426 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :      1027 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :      3433 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :      3858 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :      2446 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :      1067 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        61 elements
# Info    : Opti : (491,0,32) =  2.41817E+03 QBAD  1.67373E-01 QAVG  6.34192E-01 (   0.013 sec)
# Info    : Opti : (511,0,37) =  2.41817E+03 QBAD  2.42453E-01 QAVG  6.34654E-01 (   0.016 sec)
# Info    : Opti : no ill-shaped tets in the mesh ;-)
# Info    : Opti : 0.00 < QUAL < 0.10 :         0 elements
# Info    : Opti : 0.10 < QUAL < 0.20 :         0 elements
# Info    : Opti : 0.20 < QUAL < 0.30 :         9 elements
# Info    : Opti : 0.30 < QUAL < 0.40 :       373 elements
# Info    : Opti : 0.40 < QUAL < 0.50 :      1002 elements
# Info    : Opti : 0.50 < QUAL < 0.60 :      3473 elements
# Info    : Opti : 0.60 < QUAL < 0.70 :      3974 elements
# Info    : Opti : 0.70 < QUAL < 0.80 :      2465 elements
# Info    : Opti : 0.80 < QUAL < 0.90 :      1050 elements
# Info    : Opti : 0.90 < QUAL < 1.00 :        62 elements
# Info    : Done optimizing 3D mesh (0.053325 s)
# Info    : 4523 vertices 28434 elements
# Info    : Writing 'multi_layer_sphere.msh'...
# Info    : Done writing 'multi_layer_sphere.msh'
# Info    : Stopped on Sat Dec  1 17:22:42 2018
# [f7680fdd2aa6:07833] *** Process received signal ***
# [f7680fdd2aa6:07833] Signal: Segmentation fault (11)
# [f7680fdd2aa6:07833] Signal code: Address not mapped (1)
# [f7680fdd2aa6:07833] Failing at address: 0x7f84c241120d
# [f7680fdd2aa6:07833] [ 0] /lib/x86_64-linux-gnu/libpthread.so.0(+0x12890)[0x7f84c50bb890]
# [f7680fdd2aa6:07833] [ 1] /lib/x86_64-linux-gnu/libc.so.6(getenv+0xa5)[0x7f84c4cfa785]
# [f7680fdd2aa6:07833] [ 2] /usr/lib/x86_64-linux-gnu/libtcmalloc.so.4(_ZN13TCMallocGuardD1Ev+0x34)[0x7f84c5565e44]
# [f7680fdd2aa6:07833] [ 3] /lib/x86_64-linux-gnu/libc.so.6(__cxa_finalize+0xf5)[0x7f84c4cfb615]
# [f7680fdd2aa6:07833] [ 4] /usr/lib/x86_64-linux-gnu/libtcmalloc.so.4(+0x13cb3)[0x7f84c5563cb3]
# [f7680fdd2aa6:07833] *** End of error message ***

# %% [markdown]
# # Visualization
#
# ![alt text](https://www.csc.kth.se/~vdnguyen/images/multi_layer_sphere.png)
